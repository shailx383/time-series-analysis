# %% [markdown]
# # VISUALIZATIONS

# %% [markdown]
# Output of each function are paramters that can be used in Apache ECharts

# %%
import pandas as pd

# %% [markdown]
# ## Waterfall Plot

# %%
def waterfall_plot(df: pd.DataFrame, x: str, y: str, title: str):
    vals = df[y].to_list()
    color_labels =[]
    for i in range (1, len(vals)):
        if vals[i] > vals[i-1]:
            color_labels.append('i')
            i_list = [vals[0]]
            d_list = ['-']
        else:
            color_labels.append('d')
            i_list = ['-']
            d_list = [0]
    y = [0]
    c = 0
    for i in range(1, len(vals)):
        if color_labels[c] == 'd':
            y.append(round(vals[i], 2))
            d_list.append(round(vals[i-1] - vals[i], 2))
            i_list.append('-')
        else:
            y.append(vals[i-1])
            i_list.append(round(vals[i] - vals[i-1], 2))
            d_list.append('-')
        c += 1
    return {
        't': title,
        'x': df[x].to_list(),
        'y': y,
        'i': i_list,
        'd': d_list
    }

# %%
df = pd.read_csv('data/2/Electric_Production.csv')
df['Year'] = df['DATE'].apply(lambda x: x[-4:])
df.head()
# Out:
#        DATE  IPG2211A2N  Year
# 0  1/1/1985     72.5052  1985
# 1  2/1/1985     70.6720  1985
# 2  3/1/1985     62.4502  1985
# 3  4/1/1985     57.4714  1985
# 4  5/1/1985     55.3151  1985

# %%
df = pd.DataFrame(df[df['Year'] == '1985'])
df
# Out:
#          DATE  IPG2211A2N  Year
# 0    1/1/1985     72.5052  1985
# 1    2/1/1985     70.6720  1985
# 2    3/1/1985     62.4502  1985
# 3    4/1/1985     57.4714  1985
# 4    5/1/1985     55.3151  1985
# 5    6/1/1985     58.0904  1985
# 6    7/1/1985     62.6202  1985
# 7    8/1/1985     63.2485  1985
# 8    9/1/1985     60.5846  1985
# 9   10/1/1985     56.3154  1985
# 10  11/1/1985     58.0005  1985
# 11  12/1/1985     68.7145  1985

# %%
waterfall_plot(df, 'DATE', 'IPG2211A2N', 'Electric Production')
# Out:
# {'t': 'Electric Production',
#  'x': ['1/1/1985',
#   '2/1/1985',
#   '3/1/1985',
#   '4/1/1985',
#   '5/1/1985',
#   '6/1/1985',
#   '7/1/1985',
#   '8/1/1985',
#   '9/1/1985',
#   '10/1/1985',
#   '11/1/1985',
#   '12/1/1985'],
#  'y': [0,
#   70.67,
#   62.45,
#   57.47,
#   55.32,
#   55.3151,
#   58.0904,
#   62.6202,
#   60.58,
#   56.32,
#   56.3154,
#   58.0005],
#  'i': [72.5052, '-', '-', '-', '-', 2.78, 4.53, 0.63, '-', '-', 1.69, 10.71],
#  'd': ['-', 1.83, 8.22, 4.98, 2.16, '-', '-', '-', 2.66, 4.27, '-', '-']}

# %% [markdown]
# ## Stacked Area Plot

# %%
def stacked_area_plot(df, columns, x, title):
    return {
        'title': title,
        'names': columns,
        'vals': list(df[columns].values.T),
        'x': df[x].to_list()
    }

# %%
df = pd.read_csv('data/3/DailyDelhiClimateTrain.csv')
df
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
x = stacked_area_plot(df, ['meantemp', 'humidity', 'wind_speed', 'meanpressure'], 'date', 'Delhi weather')

# %%
x['x'][:30]
# Out:
# ['2013-01-01',
#  '2013-01-02',
#  '2013-01-03',
#  '2013-01-04',
#  '2013-01-05',
#  '2013-01-06',
#  '2013-01-07',
#  '2013-01-08',
#  '2013-01-09',
#  '2013-01-10',
#  '2013-01-11',
#  '2013-01-12',
#  '2013-01-13',
#  '2013-01-14',
#  '2013-01-15',
#  '2013-01-16',
#  '2013-01-17',
#  '2013-01-18',
#  '2013-01-19',
#  '2013-01-20',
#  '2013-01-21',
#  '2013-01-22',
#  '2013-01-23',
#  '2013-01-24',
#  '2013-01-25',
#  '2013-01-26',
#  '2013-01-27',
#  '2013-01-28',
#  '2013-01-29',
#  '2013-01-30']

# %%
[round(i/10, 3) for i in x['vals'][3][:30].tolist()], x['names'][3]
# Out:
# ([101.567,
#   101.78,
#   101.867,
#   101.717,
#   101.65,
#   101.8,
#   102.0,
#   101.871,
#   101.7,
#   101.567,
#   101.614,
#   101.557,
#   101.333,
#   101.517,
#   101.586,
#   101.667,
#   101.583,
#   101.45,
#   102.167,
#   102.029,
#   102.1,
#   102.18,
#   102.05,
#   102.05,
#   102.075,
#   101.967,
#   101.814,
#   101.783,
#   101.662,
#   101.786],
#  'meanpressure')

# %%
x['names']
# Out:
# ['meantemp', 'humidity', 'wind_speed', 'meanpressure']

# %%
x['title']
# Out:
# 'Delhi weather'

# %% [markdown]
# ## Lag Plot

# %%
from sklearn.cluster import KMeans

# %%
def lag_plot(timeseries, lag, data_reduce = 1):
    x = timeseries.values[:-lag].tolist()
    y = timeseries.values[lag:].tolist()
    data = []
    for i in range(len(x)):
        data.append([x[i], y[i]])
    kmeans = KMeans(int(len(data)/data_reduce))
    kmeans.fit(data)
    data = kmeans.cluster_centers_
    return data.tolist()

# %%
lag_plot(df['meantemp'], 3, 10)
# Out:
# /home/shail/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [[35.85739926739927, 31.507453007518798],
#  [21.04269086176981, 22.8656008465219],
#  [13.624509803921567, 12.196183473389356],
#  [27.366769547325102, 30.296835839598998],
#  [31.385592592592594, 33.822698412698415],
#  [18.405238095238097, 18.424999999999997],
#  [33.03386752136752, 30.77001322751323],
#  [25.95625, 25.88690476190476],
#  [34.51315359477124, 35.15310846560846],
#  [15.00595238095238, 16.39330357142857],
#  [31.763917795167796, 29.68836113233172],
#  [30.00934065934066, 32.34134615384615],
#  [24.93945868945869, 26.01674603174603],
#  [23.467853481261784, 21.490079365079364],
#  [6.5, 9.928571428571429],
#  [18.09027777777778, 15.6984126984127],
#  [12.616156462585037, 14.853103741496598],
#  [37.41334033613445, 37.59142857142857],
#  [27.717559523809523, 27.35054945054945],
#  [31.175925925925924, 26.687698412698413],
#  [11.504978354978356, 12.30681818181818],
#  [29.67939484126984, 30.607334799861974],
#  [31.229108470032383, 32.25285348139515],
#  [28.412306148513046, 29.3787107209521],
#  [32.618021616541355, 37.24242424242424],
#  [35.375, 27.716666666666665],
#  [28.04642857142857, 23.123809523809523],
#  [15.763690476190476, 17.9334478021978],
#  [19.69560982495765, 21.03841991341991],
#  [17.32504400361543, 19.96526360544218],
#  [18.62777777777778, 13.037500000000001],
#  [25.15654761904762, 30.65561224489796],
#  [21.486944444444443, 18.52051282051282],
#  [22.730249903605166, 23.69389063317635],
#  [28.64664502164502, 32.68948412698413],
#  [15.141794217687075, 13.943452380952381],
#  [9.53125, 9.197916666666668],
#  [37.79549319727891, 34.81853741496599],
#  [21.24702380952381, 24.992063492063494],
#  [32.011160714285715, 35.2267342032967],
#  [34.37361111111111, 33.78935185185185],
#  [12.138020833333334, 16.94142316017316],
#  [24.037450396825395, 27.593204365079366],
#  [30.655116886001444, 30.77136625826281],
#  [18.38214285714286, 23.333104395604394],
#  [17.54883658008658, 16.68574735449735],
#  [34.31785714285714, 29.724867724867725],
#  [25.21110119047619, 22.57667824074074],
#  [11.229166666666666, 15.055555555555557],
#  [20.09722222222222, 16.959656084656086],
#  [30.713541666666668, 28.81294642857143],
#  [26.848544973544975, 25.064764492753625],
#  [17.186507936507937, 13.42361111111111],
#  [33.36770833333333, 27.863508597883598],
#  [29.529571123321123, 27.453189300411523],
#  [26.8125, 37.5625],
